# %%
from deepface import DeepFace
import pandas as pd
import numpy as np
import cv2
import os
import json

# %%
img_path = 'test-img.jpg'
db_path = 'img'

# %%
result = DeepFace.find(img_path=img_path, db_path=db_path, model_name="Facenet",distance_metric='cosine', threshold=0.9)
# Out:
# 24-08-05 18:44:17 - Searching test-img.jpg in 16 length datastore
# 24-08-05 18:44:23 - find function duration 6.22027850151062 seconds
#                                              identity  \
# 0   database\Bob Morley\MV5BZTVkMjNiMDQtNDcwMy00ZT...
# 1                database\Bob Morley\589492_v9_bb.jpg
# 2   database\Vin Diesel\nZdVry7lnUkE24PnXakok9okvL...
# 3     database\Dwayne Johnson\dwayne-rock-johnson.jpg
# 4         database\Dwayne Johnson\dwayne-johnson.jpeg
# 5   database\Paul Walker\24216fcf7c31c35af47bef03d...
# 6   database\Paul Walker\243249-tn2_paul_walker_3.jpg
# 7              database\Zach McGowan\503778_v9_bc.jpg
# 8   database\Bob Morley\35a89c81f353b0cbeb9016b40f...
# 9   database\Dwayne Johnson\Dwayne_Johnson_Event_C...
# 10  database\Paul Walker\7c06864498d5f08866d6acf00...
# 11  database\Dwayne Johnson\Dwayne_Johnson_Event_C...
# 12           database\Zach McGowan\Zach-McGowan-1.jpg
# 13  database\Vin Diesel\MV5BMjExNzA4MDYxN15BMl5Ban...
# ...

# %%
# result = pd.DataFrame(result[0])
type(result[0])
# Out:
# pandas.core.frame.DataFrame

# %%
# def represent(
#     img_path: Union[str, np.ndarray],
#     model_name: str = "VGG-Face",
#     enforce_detection: bool = True,
#     detector_backend: str = "opencv",
#     align: bool = True,
#     expand_percentage: int = 0,
#     normalization: str = "base",
#     anti_spoofing: bool = False,
# )


# def find(
#     img_path: Union[str, np.ndarray],
#     db_path: str,
#     model_name: str = "VGG-Face",
#     distance_metric: str = "cosine",
#     enforce_detection: bool = True,
#     detector_backend: str = "opencv",
#     align: bool = True,
#     expand_percentage: int = 0,
#     threshold: Optional[float] = None,
#     normalization: str = "base",
#     silent: bool = False,
#     refresh_database: bool = True,
#     anti_spoofing: bool = False,
# )

# %%
model_name = ['VGG-Face', 'Facenet', 'Facenet512', 'OpenFace', 'DeepFace', 'DeepID', 'Dlib', 'ArcFace', 'SFace', 'GhostFaceNet']
detector_backend = ['opencv', 'retinaface', 'mtcnn', 'ssd', 'dlib', 'mediapipe', 'yolov8', 'centerface', 'skip']

# %%
result = DeepFace.find(
    img_path=img_path, 
    db_path=db_path, 
    model_name=model_name[0],
    distance_metric='cosine', 
    threshold=0.9,
    detector_backend=detector_backend[0],
    align=False,
    silent=True
)

# %%
result
# Out:
# [                                            identity  \
#  0  database\Bob Morley\MV5BZTVkMjNiMDQtNDcwMy00ZT...
#  1               database\Bob Morley\589492_v9_bb.jpg
#
#                                         hash  target_x  target_y  target_w  \
#  0  61221e49cf0970abf2b1b48553273448b716737f       313       252       546
#  1  cfbfc15f17b8ed36822f925a3b781920bb09fcf2        90        81       229
#
#     target_h  source_x  source_y  source_w  source_h  threshold  distance
#  0       546       132       154       472       472        0.9  0.804470
#  1       229       132       154       472       472        0.9  0.845028  ]

# %%
result = DeepFace.find(
    img_path=img_path, 
    db_path=db_path, 
    model_name=model_name[0],
    distance_metric='cosine', 
    threshold=0.9,
    detector_backend=detector_backend[2],
    align=False,
    silent=True
)
# Out:
# ...
# 1/1 [==============================] - 0s 103ms/step

# %%
result
# Out:
# [                                            identity  \
#  0  database\Bob Morley\MV5BZTVkMjNiMDQtNDcwMy00ZT...
#  1               database\Bob Morley\589492_v9_bb.jpg
#
#                                         hash  target_x  target_y  target_w  \
#  0  61221e49cf0970abf2b1b48553273448b716737f       346       207       464
#  1  cfbfc15f17b8ed36822f925a3b781920bb09fcf2        95        66       190
#
#     target_h  source_x  source_y  source_w  source_h  threshold  distance
#  0       634       189       144       354       474        0.9  0.754148
#  1       258       189       144       354       474        0.9  0.805804  ]

# %%
result = DeepFace.find(
    img_path=img_path, 
    db_path=db_path, 
    model_name=model_name[0],
    distance_metric='cosine', 
    threshold=0.9,
    detector_backend=detector_backend[3],
    align=False,
    silent=True
)

result
# Out:
# 24-08-05 19:44:28 - deploy.prototxt will be downloaded...
# Downloading...
# From: https://github.com/opencv/opencv/raw/3.4.0/samples/dnn/face_detector/deploy.prototxt
# To: C:\Users\silfa\.deepface\weights\deploy.prototxt
# 28.1kB [00:00, 2.56MB/s]
# 24-08-05 19:44:30 - res10_300x300_ssd_iter_140000.caffemodel will be downloaded...
# Downloading...
# From: https://github.com/opencv/opencv_3rdparty/raw/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel
# To: C:\Users\silfa\.deepface\weights\res10_300x300_ssd_iter_140000.caffemodel
# 100%|██████████| 10.7M/10.7M [00:26<00:00, 406kB/s]
# [                                            identity  \
#  0  database\Bob Morley\MV5BZTVkMjNiMDQtNDcwMy00ZT...
#  1               database\Bob Morley\589492_v9_bb.jpg
#
#                                         hash  target_x  target_y  target_w  \
#  0  61221e49cf0970abf2b1b48553273448b716737f       355       224       447
# ...

# %%
result = DeepFace.find(
    img_path=img_path, 
    db_path=db_path, 
    model_name=model_name[0],
    distance_metric='cosine', 
    threshold=0.9,
    detector_backend=detector_backend[4],
    align=False,
    silent=True
)

result
# Out:
# 24-08-05 20:15:21 - shape_predictor_5_face_landmarks.dat.bz2 is going to be downloaded
# Downloading...
# From: http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# To: C:\Users\silfa\.deepface\weights\shape_predictor_5_face_landmarks.dat.bz2
# 100%|██████████| 5.71M/5.71M [00:16<00:00, 341kB/s]
# [                                            identity  \
#  0  database\Bob Morley\MV5BZTVkMjNiMDQtNDcwMy00ZT...
#  1               database\Bob Morley\589492_v9_bb.jpg
#
#                                         hash  target_x  target_y  target_w  \
#  0  61221e49cf0970abf2b1b48553273448b716737f       348       348       462
#  1  cfbfc15f17b8ed36822f925a3b781920bb09fcf2       118       118       186
#
#     target_h  source_x  source_y  source_w  source_h  threshold  distance
#  0       463       161       247       385       385        0.9  0.775358
#  1       186       161       247       385       385        0.9  0.815735  ]

# %%
result = DeepFace.find(
    img_path=img_path, 
    db_path=db_path, 
    model_name=model_name[1],
    distance_metric='cosine', 
    threshold=0.9,
    detector_backend=detector_backend[0],
    align=False,
    silent=True
)

result
# Out:
# [                                             identity  \
#  0                database\Bob Morley\589492_v9_bb.jpg
#  1   database\Bob Morley\MV5BZTVkMjNiMDQtNDcwMy00ZT...
#  2         database\Dwayne Johnson\dwayne-johnson.jpeg
#  3   database\Bob Morley\35a89c81f353b0cbeb9016b40f...
#  4   database\Paul Walker\243249-tn2_paul_walker_3.jpg
#  5   database\Vin Diesel\nZdVry7lnUkE24PnXakok9okvL...
#  6     database\Dwayne Johnson\dwayne-rock-johnson.jpg
#  7              database\Zach McGowan\503778_v9_bc.jpg
#  8   database\Paul Walker\24216fcf7c31c35af47bef03d...
#  9   database\Dwayne Johnson\Dwayne_Johnson_Event_C...
#  10  database\Paul Walker\7c06864498d5f08866d6acf00...
#  11           database\Zach McGowan\Zach-McGowan-1.jpg
#  12  database\Dwayne Johnson\Dwayne_Johnson_Event_C...
#  13  database\Vin Diesel\MV5BMjExNzA4MDYxN15BMl5Ban...
#  14  database\Zach McGowan\589570284d760a427fc9e377...
#
#                                          hash  target_x  target_y  target_w  \
# ...

# %%
result = DeepFace.find(
    img_path=img_path, 
    db_path=db_path, 
    model_name=model_name[1],
    distance_metric='cosine', 
    threshold=0.9,
    detector_backend=detector_backend[1],
    align=False,
    silent=True
)

result
# Out:
# 24-08-05 20:22:51 - 🔴 Exception while extracting faces from database\Bob Morley\35a89c81f353b0cbeb9016b40f28a49f.jpg: Face could not be detected in database\Bob Morley\35a89c81f353b0cbeb9016b40f28a49f.jpg.Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# [                                             identity  \
#  0   database\Bob Morley\MV5BZTVkMjNiMDQtNDcwMy00ZT...
#  1                database\Bob Morley\589492_v9_bb.jpg
#  2   database\Paul Walker\7c06864498d5f08866d6acf00...
#  3              database\Zach McGowan\503778_v9_bc.jpg
#  4   database\Paul Walker\24216fcf7c31c35af47bef03d...
#  5   database\Paul Walker\243249-tn2_paul_walker_3.jpg
#  6         database\Dwayne Johnson\dwayne-johnson.jpeg
#  7            database\Zach McGowan\Zach-McGowan-1.jpg
#  8     database\Dwayne Johnson\dwayne-rock-johnson.jpg
#  9   database\Zach McGowan\589570284d760a427fc9e377...
#  10  database\Vin Diesel\nZdVry7lnUkE24PnXakok9okvL...
# ...

# %%
result = DeepFace.find(
    img_path=img_path, 
    db_path=db_path, 
    model_name=model_name[1],
    distance_metric='cosine', 
    threshold=0.9,
    detector_backend=detector_backend[2],
    align=False,
    silent=True
)

result
# Out:
# ...
# 1/1 [==============================] - 0s 116ms/step
# [                                             identity  \
#  0   database\Bob Morley\MV5BZTVkMjNiMDQtNDcwMy00ZT...
#  1                database\Bob Morley\589492_v9_bb.jpg
#  2              database\Zach McGowan\503778_v9_bc.jpg
#  3   database\Bob Morley\35a89c81f353b0cbeb9016b40f...
#  4   database\Paul Walker\24216fcf7c31c35af47bef03d...
#  5   database\Paul Walker\7c06864498d5f08866d6acf00...
#  6   database\Paul Walker\243249-tn2_paul_walker_3.jpg
#  7         database\Dwayne Johnson\dwayne-johnson.jpeg
#  8            database\Zach McGowan\Zach-McGowan-1.jpg
#  9   database\Zach McGowan\589570284d760a427fc9e377...
#  10  database\Dwayne Johnson\Dwayne_Johnson_Event_C...
#  11    database\Dwayne Johnson\dwayne-rock-johnson.jpg
#  12  database\Vin Diesel\MV5BMjExNzA4MDYxN15BMl5Ban...
#  13  database\Vin Diesel\nZdVry7lnUkE24PnXakok9okvL...
#
#                                          hash  target_x  target_y  target_w  \
# ...

# %%
result = DeepFace.find(
    img_path=img_path, 
    db_path=db_path, 
    model_name=model_name[1],
    distance_metric='cosine', 
    threshold=0.9,
    detector_backend=detector_backend[3],
    align=False,
    silent=True
)

result
# Out:
# [                                             identity  \
#  0   database\Bob Morley\MV5BZTVkMjNiMDQtNDcwMy00ZT...
#  1                database\Bob Morley\589492_v9_bb.jpg
#  2   database\Paul Walker\24216fcf7c31c35af47bef03d...
#  3   database\Paul Walker\7c06864498d5f08866d6acf00...
#  4         database\Dwayne Johnson\dwayne-johnson.jpeg
#  5   database\Paul Walker\243249-tn2_paul_walker_3.jpg
#  6   database\Bob Morley\35a89c81f353b0cbeb9016b40f...
#  7              database\Zach McGowan\503778_v9_bc.jpg
#  8     database\Dwayne Johnson\dwayne-rock-johnson.jpg
#  9   database\Paul Walker\24216fcf7c31c35af47bef03d...
#  10  database\Dwayne Johnson\Dwayne_Johnson_Event_C...
#  11  database\Bob Morley\35a89c81f353b0cbeb9016b40f...
#  12  database\Vin Diesel\nZdVry7lnUkE24PnXakok9okvL...
#  13  database\Vin Diesel\MV5BMjExNzA4MDYxN15BMl5Ban...
#  14               database\Bob Morley\589492_v9_bb.jpg
#  15           database\Zach McGowan\Zach-McGowan-1.jpg
# ...

# %%
result = DeepFace.find(
    img_path=img_path, 
    db_path=db_path, 
    model_name=model_name[2],
    distance_metric='cosine', 
    threshold=0.9,
    detector_backend=detector_backend[0],
    align=False,
    silent=True
)

result
# Out:
# 24-08-05 20:27:32 - facenet512_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facenet512_weights.h5
# To: C:\Users\silfa\.deepface\weights\facenet512_weights.h5
# 100%|██████████| 95.0M/95.0M [03:14<00:00, 487kB/s]
# [                                             identity  \
#  0   database\Bob Morley\MV5BZTVkMjNiMDQtNDcwMy00ZT...
#  1                database\Bob Morley\589492_v9_bb.jpg
#  2   database\Bob Morley\35a89c81f353b0cbeb9016b40f...
#  3     database\Dwayne Johnson\dwayne-rock-johnson.jpg
#  4              database\Zach McGowan\503778_v9_bc.jpg
#  5         database\Dwayne Johnson\dwayne-johnson.jpeg
#  6   database\Paul Walker\243249-tn2_paul_walker_3.jpg
#  7   database\Paul Walker\7c06864498d5f08866d6acf00...
#  8   database\Paul Walker\24216fcf7c31c35af47bef03d...
#  9   database\Vin Diesel\nZdVry7lnUkE24PnXakok9okvL...
#  10  database\Dwayne Johnson\Dwayne_Johnson_Event_C...
#
# ...

# %%
result = DeepFace.find(
    img_path=img_path, 
    db_path=db_path, 
    model_name=model_name[2],
    distance_metric='cosine', 
    threshold=0.9,
    detector_backend=detector_backend[1],
    align=False,
    silent=True
)

result
# Out:
# 24-08-05 20:36:36 - 🔴 Exception while extracting faces from database\Bob Morley\35a89c81f353b0cbeb9016b40f28a49f.jpg: Face could not be detected in database\Bob Morley\35a89c81f353b0cbeb9016b40f28a49f.jpg.Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# [                                            identity  \
#  0  database\Bob Morley\MV5BZTVkMjNiMDQtNDcwMy00ZT...
#  1               database\Bob Morley\589492_v9_bb.jpg
#  2    database\Dwayne Johnson\dwayne-rock-johnson.jpg
#  3  database\Paul Walker\243249-tn2_paul_walker_3.jpg
#  4  database\Paul Walker\7c06864498d5f08866d6acf00...
#  5        database\Dwayne Johnson\dwayne-johnson.jpeg
#  6  database\Paul Walker\24216fcf7c31c35af47bef03d...
#  7  database\Dwayne Johnson\Dwayne_Johnson_Event_C...
#  8  database\Vin Diesel\nZdVry7lnUkE24PnXakok9okvL...
#
#                                         hash  target_x  target_y  target_w  \
# ...

# %%
result = DeepFace.find(
    img_path=img_path, 
    db_path=db_path, 
    model_name=model_name[2],
    distance_metric='cosine', 
    threshold=0.9,
    detector_backend=detector_backend[-2],
    align=False,
    silent=True
)

result
# Out:
# [                                             identity  \
#  0   database\Bob Morley\MV5BZTVkMjNiMDQtNDcwMy00ZT...
#  1                database\Bob Morley\589492_v9_bb.jpg
#  2     database\Dwayne Johnson\dwayne-rock-johnson.jpg
#  3              database\Zach McGowan\503778_v9_bc.jpg
#  4   database\Bob Morley\35a89c81f353b0cbeb9016b40f...
#  5   database\Paul Walker\24216fcf7c31c35af47bef03d...
#  6   database\Paul Walker\7c06864498d5f08866d6acf00...
#  7   database\Vin Diesel\MV5BMjExNzA4MDYxN15BMl5Ban...
#  8         database\Dwayne Johnson\dwayne-johnson.jpeg
#  9   database\Paul Walker\243249-tn2_paul_walker_3.jpg
#  10  database\Vin Diesel\nZdVry7lnUkE24PnXakok9okvL...
#  11  database\Dwayne Johnson\Dwayne_Johnson_Event_C...
#
#                                          hash  target_x  target_y  target_w  \
#  0   61221e49cf0970abf2b1b48553273448b716737f       344       239       482
#  1   cfbfc15f17b8ed36822f925a3b781920bb09fcf2       106        57       188
# ...

# %%
result = DeepFace.find(
    img_path=img_path, 
    db_path=db_path, 
    model_name=model_name[2],
    distance_metric='cosine', 
    threshold=0.9,
    detector_backend=detector_backend[4],
    align=False,
    silent=True
)

result[0]
# Out:
#                                             identity  \
# 0               database\Bob Morley\589492_v9_bb.jpg
# 1  database\Bob Morley\MV5BZTVkMjNiMDQtNDcwMy00ZT...
# 2  database\Bob Morley\35a89c81f353b0cbeb9016b40f...
# 3             database\Zach McGowan\503778_v9_bc.jpg
# 4  database\Paul Walker\7c06864498d5f08866d6acf00...
# 5    database\Dwayne Johnson\dwayne-rock-johnson.jpg
# 6           database\Zach McGowan\Zach-McGowan-1.jpg
# 7  database\Paul Walker\243249-tn2_paul_walker_3.jpg
# 8        database\Dwayne Johnson\dwayne-johnson.jpeg
# 9  database\Paul Walker\24216fcf7c31c35af47bef03d...
#
#                                        hash  target_x  target_y  target_w  \
# 0  cfbfc15f17b8ed36822f925a3b781920bb09fcf2       118       118       186
# 1  61221e49cf0970abf2b1b48553273448b716737f       348       348       462
# 2  4d8dd64b3f3681c965227e513555131b953f1cc5       118       290       386
# 3  61fb7ebc2c3b619186ead4f4c98e312a4faeb527       295       357       554
# ...

# %%
result = DeepFace.find(
    img_path=img_path, 
    db_path=db_path, 
    model_name=model_name[6],
    distance_metric='cosine', 
    threshold=0.9,
    detector_backend=detector_backend[4],
    align=False,
    silent=True
)

result[0]
# Out:
#                                              identity  \
# 0   database\Bob Morley\MV5BZTVkMjNiMDQtNDcwMy00ZT...
# 1                database\Bob Morley\589492_v9_bb.jpg
# 2   database\Bob Morley\35a89c81f353b0cbeb9016b40f...
# 3            database\Zach McGowan\Zach-McGowan-1.jpg
# 4   database\Paul Walker\7c06864498d5f08866d6acf00...
# 5     database\Dwayne Johnson\dwayne-rock-johnson.jpg
# 6   database\Paul Walker\24216fcf7c31c35af47bef03d...
# 7   database\Paul Walker\243249-tn2_paul_walker_3.jpg
# 8   database\Dwayne Johnson\Dwayne_Johnson_Event_C...
# 9   database\Zach McGowan\589570284d760a427fc9e377...
# 10        database\Dwayne Johnson\dwayne-johnson.jpeg
# 11             database\Zach McGowan\503778_v9_bc.jpg
# 12  database\Vin Diesel\nZdVry7lnUkE24PnXakok9okvL...
# 13  database\Vin Diesel\MV5BMjExNzA4MDYxN15BMl5Ban...
# 14  database\Vin Diesel\vin-diesel_jpg_400x0_crop_...
#
#                                         hash  target_x  target_y  target_w  \
# ...

# %%
img_path = '1722558496_PRIMA RULIN.jpg'
db_path = 'img'

result = DeepFace.find(
    img_path=img_path, 
    db_path=db_path, 
    model_name=model_name[6],
    distance_metric='cosine', 
    threshold=0.9,
    detector_backend=detector_backend[4],
    align=False,
    silent=True
)

result[0]
# Out:
#                                              identity  \
# 0      img\B0505 PRIMA RULIN\20240621_095926_mfnr.jpg
# 1      img\B0505 PRIMA RULIN\20240621_095928_mfnr.jpg
# 2   img\P3850 AGUSNIA CANDRA KIRANA\20240621_13025...
# 3   img\P3850 AGUSNIA CANDRA KIRANA\20240621_13030...
# 4   img\P3850 AGUSNIA CANDRA KIRANA\20240621_13023...
# ..                                                ...
# 64  img\G1049 Rattyasta Rahumung Mardika\20240508_...
# 65              img\B0661 NUGROHO\20240508_142950.jpg
# 66              img\B0661 NUGROHO\20240508_143007.jpg
# 67  img\P3850 AGUSNIA CANDRA KIRANA\20240621_13025...
# 68  img\P3847 BAMBANG SUPRIYADI\20240621_135149_mf...
#
#                                         hash  target_x  target_y  target_w  \
# 0   7ba6187c9ceb27e9579c558616c1ef1505309203       332       884      1656
# 1   892e7dbe0added5b0f3cd6aa92fc6f292f41b6ad       332       884      1656
# 2   01fe0ba210706ffa9af6af2f75da2f17a96a5bf0       619      1503      1987
# ...

# %%
img_path = '1722558496_PRIMA RULIN.jpg'
db_path = 'img'

result = DeepFace.find(
    img_path=img_path, 
    db_path=db_path, 
    model_name=model_name[6],
    distance_metric='cosine', 
    threshold=0.9,
    detector_backend=detector_backend[0],
    align=False,
    silent=True
)

result[0]
# Out:
#                                              identity  \
# 0      img\B0505 PRIMA RULIN\20240621_095928_mfnr.jpg
# 1      img\B0505 PRIMA RULIN\20240621_095926_mfnr.jpg
# 2   img\P3850 AGUSNIA CANDRA KIRANA\20240621_13022...
# 3   img\P3847 BAMBANG SUPRIYADI\20240621_135142_mf...
# 4   img\P3850 AGUSNIA CANDRA KIRANA\20240621_13023...
# ..                                                ...
# 84  img\G1051 Pahlevi Wahyu Hardjita\20240508_1422...
# 85  img\P3847 BAMBANG SUPRIYADI\20240621_135130_mf...
# 86  img\G1051 Pahlevi Wahyu Hardjita\20240508_1422...
# 87  img\G1051 Pahlevi Wahyu Hardjita\20240508_1420...
# 88  img\P3847 BAMBANG SUPRIYADI\20240621_135149_mf...
#
#                                         hash  target_x  target_y  target_w  \
# 0   892e7dbe0added5b0f3cd6aa92fc6f292f41b6ad       181       539      1965
# 1   7ba6187c9ceb27e9579c558616c1ef1505309203       205       575      1915
# 2   bc07b08d381cbe9ed65f1da9d917955a380739a0       234      1108      2468
# ...

# %%
img_path = '1722558496_PRIMA RULIN.jpg'
db_path = 'img'

result = DeepFace.find(
    img_path=img_path, 
    db_path=db_path, 
    model_name=model_name[0],
    distance_metric='cosine', 
    threshold=0.9,
    detector_backend=detector_backend[0],
    align=False,
    silent=True
)

result[0]['identity', 'distance']
